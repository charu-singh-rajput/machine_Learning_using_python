# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random 
from matplotlib import style

# %%
#creating subplot
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
plt.show()

# %%
#to plot pie chart in first sub plot
plt.subplot(2,2,1)
plt.pie([1])
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
plt.show()

# %%
#to plot pie chart in sub plots
plt.subplot(2,2,1)
plt.pie([1])
plt.subplot(2,2,2)
plt.pie([1,2])
plt.subplot(2,2,3)
plt.pie([1,2,3])
plt.subplot(2,2,4)
plt.pie([1,2,3,4])
plt.show()

# %%
#to give proper spacing
plt.figure(figsize=(16,9))
plt.subplot(3,2,1)
plt.subplot(3,2,2)
plt.subplot(3,2,3)
plt.subplot(3,2,4)
plt.subplot(3,2,5)
plt.subplot(3,2,6)

plt.show()

# %%
#without comma
plt.subplot(321)
plt.show()

# %%
#to have different plots  in each subplot
plt.figure(figsize=(16,9))
plt.subplot(3,2,1)

#Line plot
days=[1,2,3,4,5,6]
chennai_temperature=[34,34,32.6,33.2,43,34.7]
delhi_temperature=[17,24,16.6,63.1,43,84.7]

style.use("ggplot")
plt.plot(days,delhi_temperature,'go--',linewidth=2,markersize=10,label="Delhi Temperature")
plt.plot(days,chennai_temperature,'ko:',linewidth=2,markersize=10,label="Chennai Temperature")
plt.title('Temperature',fontsize=25)
plt.xlabel('days',fontsize=15)
plt.ylabel('temperature',fontsize=15)
plt.grid(color='w',linestyle='-.',linewidth=1)
plt.legend(loc=4)
plt.show()
#-------------------------------------------------
plt.figure(figsize=(16,9))
plt.subplot(3,2,2)

#histogram
CLanguage_student_age=np.random.randint(18,75,(100))
Java_student_age=np.random.randint(12,80,(100))
style.use("ggplot")
bins=[10,20,30,40,50,60,70,80]
plt.hist([Java_student_age,CLanguage_student_age],bins,rwidth=0.8,histtype='bar',color=['b','m'],label=['Java Student','C Student'])
#plt.hist(CLanguage_student_age,bins,rwidth=0.8,histtype='bar',color='m',label='C Student')
plt.title("Java Student Age Group",fontsize=15)
plt.xlabel("Count",fontsize=15)
plt.ylabel("Age",fontsize=15)
plt.legend()
plt.show()

#--------------------------------------------------
plt.figure(figsize=(16,9))
plt.subplot(3,2,3)

#Bar Chart
classes=["AI","ML","DL","BD","NLP"]
class1_student=[34,56,23,45,34]
class2_student=[34,43,12,34,56]
class3_student=[21,23,23,54,31]
classes_index=np.arange(len(classes))

width=0.2

plt.bar(classes_index,class1_student,width,align='edge',color='r',label="First Class",visible=True)
plt.bar(classes_index+width,class2_student,width,align='edge',color='y',label="Second Class",visible=True)
plt.bar(classes_index+width+width,class3_student,width,align='edge',color='b',label="Third Class",visible=True)


plt.xticks(classes_index+width,classes)
plt.title("Students List",fontsize=25)
plt.xlabel("Subjects",fontsize=25)
plt.ylabel("Students",fontsize=25)
plt.legend()
plt.show()

#--------------------------------------------------
plt.figure(figsize=(16,9))
plt.subplot(3,2,4)
google_play_store_data = pd.read_csv('C:\\Users\\charu\\Desktop\\MCC\\5. FIFTH SEMESTER\\MACHINE LEARNING word\\googleplaystore.csv',nrows=1000)
x=google_play_store_data["Rating"]
y=google_play_store_data["Reviews"]
plt.scatter(x,y)

#-------------------------------------------------
plt.figure(figsize=(16,9))
plt.subplot(3,2,5)

#pie chart
colors=['r','w','r','w','r','w','r','w','r','w','r','w','r','w','r','w','r','w','r','w']
labels=np.ones(20)

plt.pie([1],colors='k',radius=2.05)
plt.pie(labels,colors=colors,radius=2.0)

plt.pie([1],colors='g',radius=1.8)
plt.pie([1],colors='y',radius=1.6)
plt.pie([1],colors='c',radius=1.3)
plt.pie([1],colors='b',radius=1.1)
plt.pie([1],colors='m',radius=0.9)

plt.pie([1],colors='b',radius=0.31)
plt.pie(labels,colors=colors,radius=0.3)

plt.pie([1],colors='w',radius=0.2)
plt.pie([1],colors='k',radius=0.1)

plt.show()

#---------------------------------------------------
plt.figure(figsize=(16,9))
plt.subplot(3,2,6,projection='polar',facecolor='k',frameon=True)
plt.show()
